# %%
#importing libraries
import pandas as pd
import mysql.connector
import numpy as np

# %%
# csv to dataframe
df_buses_1=pd.read_csv("C:/RedBus Project/Scrapped_Data/Assam.csv")
df_buses_2=pd.read_csv("C:/RedBus Project/Scrapped_Data/Andhra.csv")
df_buses_3=pd.read_csv("C:/RedBus Project/Scrapped_Data/kerala_data.csv")
df_buses_4=pd.read_csv("C:/RedBus Project/Scrapped_Data/Telangana.csv")
df_buses_5=pd.read_csv("C:/RedBus Project/Scrapped_Data/South_bengal.csv")
df_buses_6=pd.read_csv("C:/RedBus Project/Scrapped_Data/Himachal.csv")
df_buses_7=pd.read_csv("C:/RedBus Project/Scrapped_Data/Rajasthan.csv")
df_buses_8=pd.read_csv("C:/RedBus Project/Scrapped_Data/Uttarpradesh.csv")
df_buses_9=pd.read_csv("C:/RedBus Project/Scrapped_Data/Bihar.csv")
df_buses_10=pd.read_csv("C:/RedBus Project/Scrapped_Data/Westbengal.csv")

Final_df=pd.concat([df_buses_1,df_buses_2,df_buses_3,df_buses_4,df_buses_5,df_buses_6,
                    df_buses_7,df_buses_8,df_buses_9,df_buses_10],ignore_index=True)
Final_df
# Out:
#       Unnamed: 0                                           Bus_name  \
# 0              0  Assam State Transport Corporation (ASTC) - 157959
# 1              1  Assam State Transport Corporation (ASTC) - 154930
# 2              2  Assam State Transport Corporation (ASTC) - 161055
# 3              3                               Chartered Bus - ASTC
# 4              4                               Chartered Bus - ASTC
# ...          ...                                                ...
# 2381         165                                 Gogol City Service
# 2382         166                                 Gogol City Service
# 2383         167                                    Satadal Travels
# 2384         168                               Diamond City Service
# 2385         169                                 Droupadi Paribahan
#
#                                               Bus_type Start_time End_time  \
# ...

# %%
Final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2386 entries, 0 to 2385
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       2386 non-null   int64
#  1   Bus_name         2386 non-null   object
#  2   Bus_type         2386 non-null   object
#  3   Start_time       2386 non-null   object
#  4   End_time         2386 non-null   object
#  5   Total_duration   2386 non-null   object
#  6   Price            2386 non-null   object
#  7   Seats_Available  2386 non-null   object
#  8   Ratings          2386 non-null   object
#  9   Route_link       2386 non-null   object
#  10  Route_name       2386 non-null   object
# dtypes: int64(1), object(10)
# memory usage: 205.2+ KB

# %%
Final_df["Price"]=Final_df["Price"].str.replace("INR","")
Final_df["Price"]=Final_df["Price"].astype(float)
Final_df["Price"].fillna(0)
# Out:
# 0       298.00
# 1       298.00
# 2       298.00
# 3       334.68
# 4       389.13
#          ...
# 2381    148.00
# 2382    143.00
# 2383    153.00
# 2384    165.00
# 2385    160.00
# Name: Price, Length: 2386, dtype: float64

# %%
Final_df["Ratings"] = Final_df["Ratings"].astype(str)

# %%
Final_df["Ratings"] = Final_df["Ratings"].str.split('\n').str[0]

# %%
Final_df["Ratings"] = pd.to_numeric(Final_df["Ratings"], errors='coerce')

# %%
Final_df["Ratings"] = Final_df["Ratings"].fillna(0)

# %%
print(Final_df["Ratings"].tail())
# Out:
# 2381    4.1
# 2382    4.2
# 2383    4.3
# 2384    4.5
# 2385    2.6
# Name: Ratings, dtype: float64

# %%
Final_df
# Out:
#                                                Bus_name  \
# 0     Assam State Transport Corporation (ASTC) - 157959
# 1     Assam State Transport Corporation (ASTC) - 154930
# 2     Assam State Transport Corporation (ASTC) - 161055
# 3                                  Chartered Bus - ASTC
# 4                                  Chartered Bus - ASTC
# ...                                                 ...
# 2381                                 Gogol City Service
# 2382                                 Gogol City Service
# 2383                                    Satadal Travels
# 2384                               Diamond City Service
# 2385                                 Droupadi Paribahan
#
#                                               Bus_type Start_time End_time  \
# 0                         Bharat Benz A/C Seater (2+2)      14:00    18:30
# 1                                  Volvo AC Seater 2+2      15:45    20:00
# ...

# %%
# info after the data type change
Final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2386 entries, 0 to 2385
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Bus_name         2386 non-null   object
#  1   Bus_type         2386 non-null   object
#  2   Start_time       2386 non-null   object
#  3   End_time         2386 non-null   object
#  4   Total_duration   2386 non-null   object
#  5   Price            2386 non-null   float64
#  6   Seats_Available  2386 non-null   object
#  7   Ratings          2386 non-null   float64
#  8   Route_link       2386 non-null   object
#  9   Route_name       2386 non-null   object
# dtypes: float64(2), object(8)
# memory usage: 186.5+ KB

# %%
Final_df = Final_df[Final_df["Price"] <= 7000]

# %%
# replacing the nan value
Final_df = Final_df.replace({np.nan: None})

# %%
# change dataframe to csv
path=r"C:/RedBus Project/Scrapped_Data/Final_busdetails_df.csv"
Final_df.to_csv(path,index=False)

# %%
#sql connection
conn=mysql.connector.connect(host="localhost", user="root", password="Jackie@2018",database="RED_BUS_DETAILS")
my_cursor = conn.cursor()
my_cursor.execute("CREATE DATABASE IF NOT EXISTS RED_BUS_DETAILS")

# %%
# Table Creation
my_cursor.execute('''CREATE TABLE IF NOT EXISTS bus_routes(
                  ID INT AUTO_INCREMENT PRIMARY KEY,
                  Bus_name VARCHAR(255) NOT NULL,
                  Bus_type VARCHAR(255) NOT NULL,
                  Start_time VARCHAR(255) NOT NULL,
                  End_time VARCHAR(255) NOT NULL,
                  Total_duration VARCHAR(255) NOT NULL,
                  Price FLOAT NULL,
                  Seats_Available VARCHAR(255) NOT NULL,
                  Ratings Float NULL,
                  Route_link VARCHAR(255) NULL,
                  Route_name VARCHAR(255) NULL
                  )''')
print("Table Created successfully")
# Out:
# Table Created successfully

# %%
Final_df = Final_df.loc[:, ~Final_df.columns.str.contains('^Unnamed')]

# %%
data = [tuple(row) for row in Final_df.values if len(row) == 10]

# %%
data = [tuple(row) for row in Final_df.values if len(row) == 10]
print("Sample data entry:", data[0] if data else "No Data Available")
# Out:
# Sample data entry: ('Assam State Transport Corporation (ASTC) - 157959', 'Bharat Benz A/C Seater (2+2)', '14:00', '18:30', '04h 30m', 298.0, '22 Seats available', 4.2, 'https://www.redbus.in/bus-tickets/tezpur-to-guwahati', 'Tezpur to Guwahati')

# %%
conn = mysql.connector.connect(host="localhost", user="root", password="Jackie@2018", database="RED_BUS_DETAILS")
my_cursor = conn.cursor()

# %%
# SQL query to insert data into bus_details table
insert_query = '''INSERT INTO bus_routes(
                    Bus_name,
                    Bus_type,
                    Start_time,
                    End_time,
                    Total_duration,
                    Price,
                    Seats_Available,
                    Ratings,
                    Route_link,
                    Route_name)
                  VALUES(%s, %s, %s, %s, %s, %s, %s, %s, %s, %s)'''

# Insert data into the table
my_cursor.executemany(insert_query, data)

# Commit the transaction
conn.commit()

print("Values inserted successfully")
# Out:
# Values inserted successfully
